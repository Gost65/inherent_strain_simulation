# %% [markdown]
# #**Introduction**
# The goal of this code is to apply inherent strain to any dataset of *.stl* file. Written by:
# - Pierre KERFRIDEN for Inherent strain function and Fenics installation
# - Pierre LESBATS automatization
#
# Glossary:
# + IS: Inherent Strain

# %% [markdown]
# # **1-Importations and installations**
#
# ###In this section we install:
#  - [meshio](https://colab.research.google.com/drive/16BBOzDI5mIlWG-WLGyyMlWyVycS9XEML#scrollTo=PCUlyMG9bgxJ&line=3&uniqifier=1)
#  - [vtk](https://colab.research.google.com/drive/16BBOzDI5mIlWG-WLGyyMlWyVycS9XEML#scrollTo=8wEJhjWpe0wK&line=4&uniqifier=1)
#  - [FEniCS (dolfin)](https://colab.research.google.com/drive/16BBOzDI5mIlWG-WLGyyMlWyVycS9XEML#scrollTo=ZhrJA363Fulb&line=5&uniqifier=1)
#
#
# ###We import:
#  - [os and sys](https://colab.research.google.com/drive/16BBOzDI5mIlWG-WLGyyMlWyVycS9XEML#scrollTo=YZ49xWo4hADm&line=1&uniqifier=1)

# %%
#Run meshio installation:
# !pip3 install meshio==4.0.3

import meshio

print('meshio installation is done with version',  meshio.__version__)
print('Restart runtime after install meshio')
# Out:
# Collecting meshio==4.0.3
#   Downloading https://files.pythonhosted.org/packages/c5/fa/27c2234d7df673809a50f2b70c662f6d3d946d1c1bfebaf6fbb952112e59/meshio-4.0.3-py3-none-any.whl (126kB)
#      |████████████████████████████████| 133kB 9.5MB/s
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from meshio==4.0.3) (1.19.5)
# Installing collected packages: meshio
# Successfully installed meshio-4.0.3
# meshio installation is done with version 4.0.3
# Restart runtime after install meshio

# %%
#Run VTK installation:
# !pip3 install vtk

import vtk

print('installation is done and you have',vtk.vtkVersion.GetVTKSourceVersion())
# Out:
# Collecting vtk
#   Downloading https://files.pythonhosted.org/packages/b5/f5/1971e21b7da2875fa07754e49c302cdb140de4c8585d56df8027d08ce299/vtk-9.0.1-cp37-cp37m-manylinux2010_x86_64.whl (103.4MB)
#      |████████████████████████████████| 103.4MB 39kB/s
# Installing collected packages: vtk
# Successfully installed vtk-9.0.1
# installation is done and you have vtk version 9.0.1

# %%
#Run FEniCS installation:
import platform, sys
python_version=platform.python_version()
from distutils.version import LooseVersion, StrictVersion

if ( LooseVersion(python_version) < LooseVersion("3.0.0")):
    print("Python3 is needed!");
    print("How to fix: Runtime/Change_runtime_type/Python 3");
    sys.exit()

try:
    import dolfin
except ImportError as e:
    # !apt-get install -y -qq software-properties-common
    # !echo deb http://ppa.launchpad.net/fenics-packages/fenics/ubuntu bionic main >> /etc/apt/sources.list
    # !apt-key adv --keyserver keyserver.ubuntu.com --recv-keys 2C5275D7EF63D9DE2D28D3702940F5212B746472
    # !apt-get update -qq
    # !apt install -y --no-install-recommends fenics
    # !sed -i "s|#if PETSC_VERSION_MAJOR == 3 && PETSC_VERSION_MINOR <= 8 && PETSC_VERSION_RELEASE == 1|#if 1|" /usr/include/dolfin/la/PETScLUSolver.h
    # !rm -rf /usr/lib/python3/dist-packages/mpi4py*
    # !rm -rf /usr/lib/python3/dist-packages/petsc4py*
    # !rm -rf /usr/lib/python3/dist-packages/slepc4py*
    # !rm -rf /usr/lib/petsc/lib/python3/dist-packages/dolfin*
    # !rm -rf /usr/lib/petsc/lib/python3/dist-packages/mshr*
    # !wget "https://drive.google.com/uc?export=download&id=1cT_QBJCOW_eL3BThnval3bcpb8o0w-Ad" -O /tmp/mpi4py-2.0.0-cp37-cp37m-linux_x86_64.whl
    # !wget "https://drive.google.com/uc?export=download&id=119i49bxlGn1mrnhTNmOvM4BqmjrT9Ppr" -O /tmp/petsc4py-3.7.0-cp37-cp37m-linux_x86_64.whl
    # !wget "https://drive.google.com/uc?export=download&id=1-1tVfu8qz3bRC2zvR8n3RESpesWqNnn6" -O /tmp/slepc4py-3.7.0-cp37-cp37m-linux_x86_64.whl
    # !wget "https://drive.google.com/uc?export=download&id=1-3qY4VIJQaXVO1HfGQIzTIURIeJbvX-9" -O /tmp/fenics_dolfin-2019.2.0.dev0-cp37-cp37m-linux_x86_64.whl
    # !wget "https://drive.google.com/uc?export=download&id=1-5SMjgjMuee_9WLeYtGe8N_lvipWEN7W" -O /tmp/mshr-2019.2.0.dev0-cp37-cp37m-linux_x86_64.whl
    # !pip3 install /tmp/mpi4py-2.0.0-cp37-cp37m-linux_x86_64.whl --upgrade
    # !pip3 install /tmp/petsc4py-3.7.0-cp37-cp37m-linux_x86_64.whl --upgrade
    # !pip3 install /tmp/slepc4py-3.7.0-cp37-cp37m-linux_x86_64.whl --upgrade
    # !pip3 install /tmp/fenics_dolfin-2019.2.0.dev0-cp37-cp37m-linux_x86_64.whl --upgrade
    # !pip3 install /tmp/mshr-2019.2.0.dev0-cp37-cp37m-linux_x86_64.whl --upgrade
    # !pip3 -q install --upgrade sympy
    import dolfin
  
from IPython.display import clear_output, display; import time; import dolfin.common.plotting as fenicsplot 


#on confirme que dolphin, module de Fenics, est bien là
dolfin_version = dolfin.__version__
print ('Dolfin installation is done with version', dolfin_version)
#si y'a un soucis tu fait "Excécution -> redémarrer l'environnement d'excécution" et tu run a nouveau le code.
#!rm -rf * # clean up all files and Drive Be careful


# Useful commands
# Remove an empty folder      : os.rmdir("my_results")
# Remove a folder with files  : shutil.rmtree("results")
# Make a folder               : os.mkdir("my_results")
# Runtime/Change_runtime_type/Python3
# Out:
# Executing: /tmp/apt-key-gpghome.AThbhUWIp0/gpg.1.sh --keyserver keyserver.ubuntu.com --recv-keys 2C5275D7EF63D9DE2D28D3702940F5212B746472
# gpg: key 2940F5212B746472: public key "Launchpad PPA for FEniCS Packages Team" imported
# gpg: Total number processed: 1
# gpg:               imported: 1
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following additional packages will be installed:
#   dolfin-bin dolfin-doc fonts-font-awesome fonts-lato libamd2 libbtf1 libcamd2
#   libccolamd2 libcholmod3 libcolamd2 libcxsparse3 libdolfin-dev
#   libdolfin-dev-common libdolfin2019.2 libeigen3-dev libfftw3-bin libfftw3-dev
#   libfftw3-long3 libfftw3-mpi-dev libfftw3-mpi3 libfftw3-quad3
#   libfftw3-single3 libgraphblas1 libhdf5-mpi-dev libhdf5-openmpi-dev
#   libhypre-2.13.0 libhypre-dev libjs-jquery libjs-modernizr libjs-sphinxdoc
#   libjs-underscore libklu1 libldl2 libmetis5 libmshr-dev libmshr-dev-common
#   libmshr2019.2 libmumps-5.1.2 libmumps-dev libparpack2 libparpack2-dev
#   libpetsc3.7.7 libpetsc3.7.7-dev libptscotch-6.0 libptscotch-dev librbio2
#   libscalapack-mpi-dev libscalapack-openmpi-dev libscalapack-openmpi2.0
#   libscotch-6.0 libscotch-dev libslepc3.7.4 libslepc3.7.4-dev libspooles-dev
#   libspooles2.2 libspqr2 libsuitesparse-dev libsuitesparseconfig5
#   libsuperlu-dist5 libtet1.5 libumfpack5 pybind11-dev python-ufl-doc
#   python3-dijitso python3-dolfin python3-dolfin-real python3-ffc python3-fiat
#   python3-mpi4py python3-mpmath python3-mshr python3-mshr-real python3-numpy
#   python3-petsc4py python3-pkg-resources python3-pkgconfig python3-ply
#   python3-pybind11 python3-six python3-slepc4py python3-sympy python3-ufl
#   sphinx-rtd-theme-common
# Suggested packages:
#   libeigen3-doc libmrpt-dev libfftw3-doc libhdf5-doc petsc-dev
#   libpetsc3.7.7-dbg petsc3.7.7-doc libluminate-dev scalapack-doc
#   slepc3.7.4-doc spooles-doc pybind11-doc python-dijitso-doc python3-gmpy2
#   python3-matplotlib python-mpmath-doc python-numpy-doc python3-nose
#   python3-numpy-dbg python3-setuptools python-ply-doc texlive-fonts-extra
#   dvipng python-sympy-doc
# Recommended packages:
#   python3-matplotlib javascript-common tcsh | csh | c-shell ksh | mksh | pdksh
#   | zsh python-petsc4py-docs python-slepc4py-docs python3-pil ipython3
# The following NEW packages will be installed:
#   dolfin-bin dolfin-doc fenics fonts-font-awesome fonts-lato libamd2 libbtf1
#   libcamd2 libccolamd2 libcholmod3 libcolamd2 libcxsparse3 libdolfin-dev
#   libdolfin-dev-common libdolfin2019.2 libeigen3-dev libfftw3-bin libfftw3-dev
#   libfftw3-long3 libfftw3-mpi-dev libfftw3-mpi3 libfftw3-quad3
#   libfftw3-single3 libgraphblas1 libhdf5-mpi-dev libhdf5-openmpi-dev
#   libhypre-2.13.0 libhypre-dev libjs-jquery libjs-modernizr libjs-sphinxdoc
#   libjs-underscore libklu1 libldl2 libmetis5 libmshr-dev libmshr-dev-common
#   libmshr2019.2 libmumps-5.1.2 libmumps-dev libparpack2 libparpack2-dev
#   libpetsc3.7.7 libpetsc3.7.7-dev libptscotch-6.0 libptscotch-dev librbio2
#   libscalapack-mpi-dev libscalapack-openmpi-dev libscalapack-openmpi2.0
#   libscotch-6.0 libscotch-dev libslepc3.7.4 libslepc3.7.4-dev libspooles-dev
#   libspooles2.2 libspqr2 libsuitesparse-dev libsuitesparseconfig5
#   libsuperlu-dist5 libtet1.5 libumfpack5 pybind11-dev python-ufl-doc
#   python3-dijitso python3-dolfin python3-dolfin-real python3-ffc python3-fiat
#   python3-mpi4py python3-mpmath python3-mshr python3-mshr-real python3-numpy
#   python3-petsc4py python3-pkg-resources python3-pkgconfig python3-ply
#   python3-pybind11 python3-six python3-slepc4py python3-sympy python3-ufl
#   sphinx-rtd-theme-common
# 0 upgraded, 84 newly installed, 0 to remove and 45 not upgraded.
# Need to get 62.6 MB of archives.
# After this operation, 329 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/main amd64 fonts-lato all 2.0-2 [2,698 kB]
# Get:2 http://ppa.launchpad.net/fenics-packages/fenics/ubuntu bionic/main amd64 libdolfin-dev-common all 2019.2.0~git20201207.b495043-4~ppa1~bionic6 [205 kB]
# Get:3 http://ppa.launchpad.net/fenics-packages/fenics/ubuntu bionic/main amd64 libdolfin2019.2 amd64 2019.2.0~git20201207.b495043-4~ppa1~bionic6 [1,768 kB]
# Get:4 http://archive.ubuntu.com/ubuntu bionic/main amd64 libsuitesparseconfig5 amd64 1:5.1.2-2 [9,044 B]
# Get:5 http://archive.ubuntu.com/ubuntu bionic/main amd64 libamd2 amd64 1:5.1.2-2 [19.5 kB]
# Get:6 http://archive.ubuntu.com/ubuntu bionic/main amd64 libcamd2 amd64 1:5.1.2-2 [20.9 kB]
# Get:7 http://archive.ubuntu.com/ubuntu bionic/main amd64 libccolamd2 amd64 1:5.1.2-2 [21.7 kB]
# Get:8 http://archive.ubuntu.com/ubuntu bionic/main amd64 libcolamd2 amd64 1:5.1.2-2 [16.2 kB]
# Get:9 http://archive.ubuntu.com/ubuntu bionic/main amd64 libmetis5 amd64 5.1.0.dfsg-5 [169 kB]
# Get:10 http://archive.ubuntu.com/ubuntu bionic/main amd64 libcholmod3 amd64 1:5.1.2-2 [300 kB]
# Get:11 http://archive.ubuntu.com/ubuntu bionic/main amd64 libfftw3-long3 amd64 3.3.7-1 [308 kB]
# Get:12 http://archive.ubuntu.com/ubuntu bionic/main amd64 libfftw3-single3 amd64 3.3.7-1 [764 kB]
# Get:13 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libfftw3-mpi3 amd64 3.3.7-1 [47.5 kB]
# Get:14 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libscotch-6.0 amd64 6.0.4.dfsg1-8 [403 kB]
# Get:15 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libptscotch-6.0 amd64 6.0.4.dfsg1-8 [654 kB]
# Get:16 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libsuperlu-dist5 amd64 5.3.0+dfsg1-1 [213 kB]
# Get:17 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libhypre-2.13.0 amd64 2.13.0-2 [1,718 kB]
# Get:18 http://archive.ubuntu.com/ubuntu bionic/main amd64 libbtf1 amd64 1:5.1.2-2 [10.6 kB]
# Get:19 http://archive.ubuntu.com/ubuntu bionic/main amd64 libklu1 amd64 1:5.1.2-2 [69.3 kB]
# Get:20 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libscalapack-openmpi2.0 amd64 2.0.2-4 [1,473 kB]
# Get:21 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libmumps-5.1.2 amd64 5.1.2-4 [1,103 kB]
# Get:22 http://archive.ubuntu.com/ubuntu bionic/main amd64 libumfpack5 amd64 1:5.1.2-2 [229 kB]
# Get:23 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libpetsc3.7.7 amd64 3.7.7+dfsg1-2build5 [3,935 kB]
# Get:24 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libparpack2 amd64 3.5.0+real-2 [84.5 kB]
# Get:25 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libslepc3.7.4 amd64 3.7.4+dfsg1-2build8 [743 kB]
# Get:26 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libeigen3-dev all 3.3.4-4 [810 kB]
# Get:27 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libhdf5-openmpi-dev amd64 1.10.0-patch1+docs-4 [2,392 kB]
# Get:28 http://ppa.launchpad.net/fenics-packages/fenics/ubuntu bionic/main amd64 python3-fiat all 2019.2.0~git20210116.0439689-3~ppa1~bionic2 [68.7 kB]
# Get:29 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libhdf5-mpi-dev amd64 1.10.0-patch1+docs-4 [3,074 B]
# Get:30 http://archive.ubuntu.com/ubuntu bionic/main amd64 libcxsparse3 amd64 1:5.1.2-2 [63.9 kB]
# Get:31 http://archive.ubuntu.com/ubuntu bionic/main amd64 libgraphblas1 amd64 1:5.1.2-2 [384 kB]
# Get:32 http://archive.ubuntu.com/ubuntu bionic/main amd64 libldl2 amd64 1:5.1.2-2 [10.3 kB]
# Get:33 http://archive.ubuntu.com/ubuntu bionic/main amd64 librbio2 amd64 1:5.1.2-2 [24.0 kB]
# Get:34 http://archive.ubuntu.com/ubuntu bionic/main amd64 libspqr2 amd64 1:5.1.2-2 [64.2 kB]
# Get:35 http://archive.ubuntu.com/ubuntu bionic/main amd64 libsuitesparse-dev amd64 1:5.1.2-2 [1,235 kB]
# Get:36 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libscotch-dev amd64 6.0.4.dfsg1-8 [1,791 kB]
# Get:37 http://archive.ubuntu.com/ubuntu bionic/main amd64 python3-numpy amd64 1:1.13.3-2ubuntu1 [1,943 kB]
# Get:38 http://archive.ubuntu.com/ubuntu bionic/universe amd64 python3-mpmath all 1.0.0-1 [400 kB]
# Get:39 http://archive.ubuntu.com/ubuntu bionic/universe amd64 python3-sympy all 1.1.1-5 [2,569 kB]
# Get:40 http://archive.ubuntu.com/ubuntu bionic/main amd64 python3-pkg-resources all 39.0.1-2 [98.8 kB]
# Get:41 http://archive.ubuntu.com/ubuntu bionic/universe amd64 python3-mpi4py amd64 2.0.0-3 [420 kB]
# Get:42 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libspooles2.2 amd64 2.2-12build1 [458 kB]
# Get:43 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libspooles-dev amd64 2.2-12build1 [587 kB]
# Get:44 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libhypre-dev amd64 2.13.0-2 [134 kB]
# Get:45 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libptscotch-dev amd64 6.0.4.dfsg1-8 [5,416 kB]
# Get:46 http://ppa.launchpad.net/fenics-packages/fenics/ubuntu bionic/main amd64 python3-ufl all 2019.2.0~git20210211.d60cd09-1~ppa1~bionic1 [150 kB]
# Get:47 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libscalapack-openmpi-dev amd64 2.0.2-4 [6,068 B]
# Get:48 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libscalapack-mpi-dev amd64 2.0.2-4 [2,108 B]
# Get:49 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libmumps-dev amd64 5.1.2-4 [984 kB]
# Get:50 http://archive.ubuntu.com/ubuntu bionic/main amd64 libfftw3-quad3 amd64 3.3.7-1 [552 kB]
# Get:51 http://archive.ubuntu.com/ubuntu bionic/main amd64 libfftw3-bin amd64 3.3.7-1 [32.7 kB]
# Get:52 http://archive.ubuntu.com/ubuntu bionic/main amd64 libfftw3-dev amd64 3.3.7-1 [2,108 kB]
# Get:53 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libfftw3-mpi-dev amd64 3.3.7-1 [47.6 kB]
# Get:54 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libpetsc3.7.7-dev amd64 3.7.7+dfsg1-2build5 [3,495 kB]
# Get:55 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libparpack2-dev amd64 3.5.0+real-2 [92.0 kB]
# Get:56 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libslepc3.7.4-dev amd64 3.7.4+dfsg1-2build8 [1,701 kB]
# Get:57 http://archive.ubuntu.com/ubuntu bionic/universe amd64 python3-petsc4py amd64 3.7.0-3build2 [719 kB]
# Get:58 http://archive.ubuntu.com/ubuntu bionic/universe amd64 python3-slepc4py amd64 3.7.0-3build1 [155 kB]
# Get:59 http://archive.ubuntu.com/ubuntu bionic/main amd64 python3-ply all 3.11-1 [46.6 kB]
# Get:60 http://archive.ubuntu.com/ubuntu bionic/main amd64 python3-six all 1.11.0-2 [11.4 kB]
# Get:61 http://archive.ubuntu.com/ubuntu bionic/universe amd64 python3-pkgconfig all 1.3.1-1 [6,328 B]
# Get:62 http://archive.ubuntu.com/ubuntu bionic/main amd64 libjs-jquery all 3.2.1-1 [152 kB]
# Get:63 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libjs-underscore all 1.8.3~dfsg-1ubuntu0.1 [60.4 kB]
# Get:64 http://archive.ubuntu.com/ubuntu bionic/main amd64 libjs-sphinxdoc all 1.6.7-1ubuntu1 [85.6 kB]
# Get:65 http://archive.ubuntu.com/ubuntu bionic/main amd64 fonts-font-awesome all 4.7.0~dfsg-3 [513 kB]
# Get:66 http://ppa.launchpad.net/fenics-packages/fenics/ubuntu bionic/main amd64 python3-dijitso all 2019.2.0~git20190418.c92dcb0-2~ppa1~bionic3 [24.6 kB]
# Get:67 http://archive.ubuntu.com/ubuntu bionic/main amd64 libjs-modernizr all 2.6.2+ds1-1ubuntu1 [46.7 kB]
# Get:68 http://archive.ubuntu.com/ubuntu bionic/main amd64 sphinx-rtd-theme-common all 0.2.4-1 [224 kB]
# Get:69 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libtet1.5 amd64 1.5.0-4 [235 kB]
# Get:70 http://ppa.launchpad.net/fenics-packages/fenics/ubuntu bionic/main amd64 python3-ffc all 2019.2.0~git20210115.cb26c91-1~ppa1~bionic1 [226 kB]
# Get:71 http://ppa.launchpad.net/fenics-packages/fenics/ubuntu bionic/main amd64 libdolfin-dev amd64 2019.2.0~git20201207.b495043-4~ppa1~bionic6 [26.8 kB]
# Get:72 http://ppa.launchpad.net/fenics-packages/fenics/ubuntu bionic/main amd64 python3-dolfin-real amd64 2019.2.0~git20201207.b495043-4~ppa1~bionic6 [720 kB]
# Get:73 http://ppa.launchpad.net/fenics-packages/fenics/ubuntu bionic/main amd64 pybind11-dev all 2.2.3-1fenics1bionic1 [129 kB]
# Get:74 http://ppa.launchpad.net/fenics-packages/fenics/ubuntu bionic/main amd64 python3-pybind11 all 2.2.3-1fenics1bionic1 [21.5 kB]
# Get:75 http://ppa.launchpad.net/fenics-packages/fenics/ubuntu bionic/main amd64 python3-dolfin amd64 2019.2.0~git20201207.b495043-4~ppa1~bionic6 [40.3 kB]
# Get:76 http://ppa.launchpad.net/fenics-packages/fenics/ubuntu bionic/main amd64 dolfin-bin all 2019.2.0~git20201207.b495043-4~ppa1~bionic6 [27.3 kB]
# Get:77 http://ppa.launchpad.net/fenics-packages/fenics/ubuntu bionic/main amd64 dolfin-doc all 2019.2.0~git20201207.b495043-4~ppa1~bionic6 [12.5 MB]
# Get:78 http://ppa.launchpad.net/fenics-packages/fenics/ubuntu bionic/main amd64 python-ufl-doc all 2019.2.0~git20210211.d60cd09-1~ppa1~bionic1 [14.0 kB]
# Get:79 http://ppa.launchpad.net/fenics-packages/fenics/ubuntu bionic/main amd64 libmshr2019.2 amd64 2019.2.0~git20200924.c27eb18+git1-2~ppa1~bionic4 [1,467 kB]
# Get:80 http://ppa.launchpad.net/fenics-packages/fenics/ubuntu bionic/main amd64 libmshr-dev-common amd64 2019.2.0~git20200924.c27eb18+git1-2~ppa1~bionic4 [16.2 kB]
# Get:81 http://ppa.launchpad.net/fenics-packages/fenics/ubuntu bionic/main amd64 libmshr-dev amd64 2019.2.0~git20200924.c27eb18+git1-2~ppa1~bionic4 [52.6 kB]
# Get:82 http://ppa.launchpad.net/fenics-packages/fenics/ubuntu bionic/main amd64 python3-mshr-real amd64 2019.2.0~git20200924.c27eb18+git1-2~ppa1~bionic4 [88.1 kB]
# Get:83 http://ppa.launchpad.net/fenics-packages/fenics/ubuntu bionic/main amd64 python3-mshr all 2019.2.0~git20200924.c27eb18+git1-2~ppa1~bionic4 [9,484 B]
# Get:84 http://ppa.launchpad.net/fenics-packages/fenics/ubuntu bionic/main amd64 fenics amd64 1:2019.2.0.5~ppa1~bionic1 [4,908 B]
# Fetched 62.6 MB in 14s (4,577 kB/s)
# Extracting templates from packages: 100%
# Selecting previously unselected package fonts-lato.
# (Reading database ... 160772 files and directories currently installed.)
# Preparing to unpack .../00-fonts-lato_2.0-2_all.deb ...
# Unpacking fonts-lato (2.0-2) ...
# Selecting previously unselected package libdolfin-dev-common.
# Preparing to unpack .../01-libdolfin-dev-common_2019.2.0~git20201207.b495043-4~ppa1~bionic6_all.deb ...
# Unpacking libdolfin-dev-common (2019.2.0~git20201207.b495043-4~ppa1~bionic6) ...
# Selecting previously unselected package libsuitesparseconfig5:amd64.
# Preparing to unpack .../02-libsuitesparseconfig5_1%3a5.1.2-2_amd64.deb ...
# Unpacking libsuitesparseconfig5:amd64 (1:5.1.2-2) ...
# Selecting previously unselected package libamd2:amd64.
# Preparing to unpack .../03-libamd2_1%3a5.1.2-2_amd64.deb ...
# Unpacking libamd2:amd64 (1:5.1.2-2) ...
# Selecting previously unselected package libcamd2:amd64.
# Preparing to unpack .../04-libcamd2_1%3a5.1.2-2_amd64.deb ...
# Unpacking libcamd2:amd64 (1:5.1.2-2) ...
# Selecting previously unselected package libccolamd2:amd64.
# Preparing to unpack .../05-libccolamd2_1%3a5.1.2-2_amd64.deb ...
# Unpacking libccolamd2:amd64 (1:5.1.2-2) ...
# Selecting previously unselected package libcolamd2:amd64.
# Preparing to unpack .../06-libcolamd2_1%3a5.1.2-2_amd64.deb ...
# Unpacking libcolamd2:amd64 (1:5.1.2-2) ...
# Selecting previously unselected package libmetis5:amd64.
# Preparing to unpack .../07-libmetis5_5.1.0.dfsg-5_amd64.deb ...
# Unpacking libmetis5:amd64 (5.1.0.dfsg-5) ...
# Selecting previously unselected package libcholmod3:amd64.
# Preparing to unpack .../08-libcholmod3_1%3a5.1.2-2_amd64.deb ...
# Unpacking libcholmod3:amd64 (1:5.1.2-2) ...
# Selecting previously unselected package libfftw3-long3:amd64.
# Preparing to unpack .../09-libfftw3-long3_3.3.7-1_amd64.deb ...
# Unpacking libfftw3-long3:amd64 (3.3.7-1) ...
# Selecting previously unselected package libfftw3-single3:amd64.
# Preparing to unpack .../10-libfftw3-single3_3.3.7-1_amd64.deb ...
# Unpacking libfftw3-single3:amd64 (3.3.7-1) ...
# Selecting previously unselected package libfftw3-mpi3:amd64.
# Preparing to unpack .../11-libfftw3-mpi3_3.3.7-1_amd64.deb ...
# Unpacking libfftw3-mpi3:amd64 (3.3.7-1) ...
# Selecting previously unselected package libscotch-6.0.
# Preparing to unpack .../12-libscotch-6.0_6.0.4.dfsg1-8_amd64.deb ...
# Unpacking libscotch-6.0 (6.0.4.dfsg1-8) ...
# Selecting previously unselected package libptscotch-6.0.
# Preparing to unpack .../13-libptscotch-6.0_6.0.4.dfsg1-8_amd64.deb ...
# Unpacking libptscotch-6.0 (6.0.4.dfsg1-8) ...
# Selecting previously unselected package libsuperlu-dist5.
# Preparing to unpack .../14-libsuperlu-dist5_5.3.0+dfsg1-1_amd64.deb ...
# Unpacking libsuperlu-dist5 (5.3.0+dfsg1-1) ...
# Selecting previously unselected package libhypre-2.13.0:amd64.
# Preparing to unpack .../15-libhypre-2.13.0_2.13.0-2_amd64.deb ...
# Unpacking libhypre-2.13.0:amd64 (2.13.0-2) ...
# Selecting previously unselected package libbtf1:amd64.
# Preparing to unpack .../16-libbtf1_1%3a5.1.2-2_amd64.deb ...
# Unpacking libbtf1:amd64 (1:5.1.2-2) ...
# Selecting previously unselected package libklu1:amd64.
# Preparing to unpack .../17-libklu1_1%3a5.1.2-2_amd64.deb ...
# Unpacking libklu1:amd64 (1:5.1.2-2) ...
# Selecting previously unselected package libscalapack-openmpi2.0.
# Preparing to unpack .../18-libscalapack-openmpi2.0_2.0.2-4_amd64.deb ...
# Unpacking libscalapack-openmpi2.0 (2.0.2-4) ...
# Selecting previously unselected package libmumps-5.1.2:amd64.
# Preparing to unpack .../19-libmumps-5.1.2_5.1.2-4_amd64.deb ...
# Unpacking libmumps-5.1.2:amd64 (5.1.2-4) ...
# Selecting previously unselected package libumfpack5:amd64.
# Preparing to unpack .../20-libumfpack5_1%3a5.1.2-2_amd64.deb ...
# Unpacking libumfpack5:amd64 (1:5.1.2-2) ...
# Selecting previously unselected package libpetsc3.7.7:amd64.
# Preparing to unpack .../21-libpetsc3.7.7_3.7.7+dfsg1-2build5_amd64.deb ...
# Unpacking libpetsc3.7.7:amd64 (3.7.7+dfsg1-2build5) ...
# Selecting previously unselected package libparpack2:amd64.
# Preparing to unpack .../22-libparpack2_3.5.0+real-2_amd64.deb ...
# Unpacking libparpack2:amd64 (3.5.0+real-2) ...
# Selecting previously unselected package libslepc3.7.4.
# Preparing to unpack .../23-libslepc3.7.4_3.7.4+dfsg1-2build8_amd64.deb ...
# Unpacking libslepc3.7.4 (3.7.4+dfsg1-2build8) ...
# Selecting previously unselected package libdolfin2019.2:amd64.
# Preparing to unpack .../24-libdolfin2019.2_2019.2.0~git20201207.b495043-4~ppa1~bionic6_amd64.deb ...
# Unpacking libdolfin2019.2:amd64 (2019.2.0~git20201207.b495043-4~ppa1~bionic6) ...
# Selecting previously unselected package libeigen3-dev.
# Preparing to unpack .../25-libeigen3-dev_3.3.4-4_all.deb ...
# Unpacking libeigen3-dev (3.3.4-4) ...
# Selecting previously unselected package libhdf5-openmpi-dev.
# Preparing to unpack .../26-libhdf5-openmpi-dev_1.10.0-patch1+docs-4_amd64.deb ...
# Unpacking libhdf5-openmpi-dev (1.10.0-patch1+docs-4) ...
# Selecting previously unselected package libhdf5-mpi-dev.
# Preparing to unpack .../27-libhdf5-mpi-dev_1.10.0-patch1+docs-4_amd64.deb ...
# Unpacking libhdf5-mpi-dev (1.10.0-patch1+docs-4) ...
# Selecting previously unselected package libcxsparse3:amd64.
# Preparing to unpack .../28-libcxsparse3_1%3a5.1.2-2_amd64.deb ...
# Unpacking libcxsparse3:amd64 (1:5.1.2-2) ...
# Selecting previously unselected package libgraphblas1:amd64.
# Preparing to unpack .../29-libgraphblas1_1%3a5.1.2-2_amd64.deb ...
# Unpacking libgraphblas1:amd64 (1:5.1.2-2) ...
# Selecting previously unselected package libldl2:amd64.
# Preparing to unpack .../30-libldl2_1%3a5.1.2-2_amd64.deb ...
# Unpacking libldl2:amd64 (1:5.1.2-2) ...
# Selecting previously unselected package librbio2:amd64.
# Preparing to unpack .../31-librbio2_1%3a5.1.2-2_amd64.deb ...
# Unpacking librbio2:amd64 (1:5.1.2-2) ...
# Selecting previously unselected package libspqr2:amd64.
# Preparing to unpack .../32-libspqr2_1%3a5.1.2-2_amd64.deb ...
# Unpacking libspqr2:amd64 (1:5.1.2-2) ...
# Selecting previously unselected package libsuitesparse-dev:amd64.
# Preparing to unpack .../33-libsuitesparse-dev_1%3a5.1.2-2_amd64.deb ...
# Unpacking libsuitesparse-dev:amd64 (1:5.1.2-2) ...
# Selecting previously unselected package libscotch-dev.
# Preparing to unpack .../34-libscotch-dev_6.0.4.dfsg1-8_amd64.deb ...
# Unpacking libscotch-dev (6.0.4.dfsg1-8) ...
# Selecting previously unselected package python3-numpy.
# Preparing to unpack .../35-python3-numpy_1%3a1.13.3-2ubuntu1_amd64.deb ...
# Unpacking python3-numpy (1:1.13.3-2ubuntu1) ...
# Selecting previously unselected package python3-mpmath.
# Preparing to unpack .../36-python3-mpmath_1.0.0-1_all.deb ...
# Unpacking python3-mpmath (1.0.0-1) ...
# Selecting previously unselected package python3-sympy.
# Preparing to unpack .../37-python3-sympy_1.1.1-5_all.deb ...
# Unpacking python3-sympy (1.1.1-5) ...
# Selecting previously unselected package python3-pkg-resources.
# Preparing to unpack .../38-python3-pkg-resources_39.0.1-2_all.deb ...
# Unpacking python3-pkg-resources (39.0.1-2) ...
# Selecting previously unselected package python3-fiat.
# Preparing to unpack .../39-python3-fiat_2019.2.0~git20210116.0439689-3~ppa1~bionic2_all.deb ...
# Unpacking python3-fiat (2019.2.0~git20210116.0439689-3~ppa1~bionic2) ...
# Selecting previously unselected package python3-ufl.
# Preparing to unpack .../40-python3-ufl_2019.2.0~git20210211.d60cd09-1~ppa1~bionic1_all.deb ...
# Unpacking python3-ufl (2019.2.0~git20210211.d60cd09-1~ppa1~bionic1) ...
# Selecting previously unselected package python3-mpi4py.
# Preparing to unpack .../41-python3-mpi4py_2.0.0-3_amd64.deb ...
# Unpacking python3-mpi4py (2.0.0-3) ...
# Selecting previously unselected package python3-dijitso.
# Preparing to unpack .../42-python3-dijitso_2019.2.0~git20190418.c92dcb0-2~ppa1~bionic3_all.deb ...
# Unpacking python3-dijitso (2019.2.0~git20190418.c92dcb0-2~ppa1~bionic3) ...
# Selecting previously unselected package python3-ffc.
# Preparing to unpack .../43-python3-ffc_2019.2.0~git20210115.cb26c91-1~ppa1~bionic1_all.deb ...
# Unpacking python3-ffc (2019.2.0~git20210115.cb26c91-1~ppa1~bionic1) ...
# Selecting previously unselected package libspooles2.2:amd64.
# Preparing to unpack .../44-libspooles2.2_2.2-12build1_amd64.deb ...
# Unpacking libspooles2.2:amd64 (2.2-12build1) ...
# Selecting previously unselected package libspooles-dev:amd64.
# Preparing to unpack .../45-libspooles-dev_2.2-12build1_amd64.deb ...
# Unpacking libspooles-dev:amd64 (2.2-12build1) ...
# Selecting previously unselected package libhypre-dev:amd64.
# Preparing to unpack .../46-libhypre-dev_2.13.0-2_amd64.deb ...
# Unpacking libhypre-dev:amd64 (2.13.0-2) ...
# Selecting previously unselected package libptscotch-dev.
# Preparing to unpack .../47-libptscotch-dev_6.0.4.dfsg1-8_amd64.deb ...
# Unpacking libptscotch-dev (6.0.4.dfsg1-8) ...
# Selecting previously unselected package libscalapack-openmpi-dev.
# Preparing to unpack .../48-libscalapack-openmpi-dev_2.0.2-4_amd64.deb ...
# Unpacking libscalapack-openmpi-dev (2.0.2-4) ...
# Selecting previously unselected package libscalapack-mpi-dev.
# Preparing to unpack .../49-libscalapack-mpi-dev_2.0.2-4_amd64.deb ...
# Unpacking libscalapack-mpi-dev (2.0.2-4) ...
# Selecting previously unselected package libmumps-dev:amd64.
# Preparing to unpack .../50-libmumps-dev_5.1.2-4_amd64.deb ...
# Unpacking libmumps-dev:amd64 (5.1.2-4) ...
# Selecting previously unselected package libfftw3-quad3:amd64.
# Preparing to unpack .../51-libfftw3-quad3_3.3.7-1_amd64.deb ...
# Unpacking libfftw3-quad3:amd64 (3.3.7-1) ...
# Selecting previously unselected package libfftw3-bin.
# Preparing to unpack .../52-libfftw3-bin_3.3.7-1_amd64.deb ...
# Unpacking libfftw3-bin (3.3.7-1) ...
# Selecting previously unselected package libfftw3-dev:amd64.
# Preparing to unpack .../53-libfftw3-dev_3.3.7-1_amd64.deb ...
# Unpacking libfftw3-dev:amd64 (3.3.7-1) ...
# Selecting previously unselected package libfftw3-mpi-dev:amd64.
# Preparing to unpack .../54-libfftw3-mpi-dev_3.3.7-1_amd64.deb ...
# Unpacking libfftw3-mpi-dev:amd64 (3.3.7-1) ...
# Selecting previously unselected package libpetsc3.7.7-dev:amd64.
# Preparing to unpack .../55-libpetsc3.7.7-dev_3.7.7+dfsg1-2build5_amd64.deb ...
# Unpacking libpetsc3.7.7-dev:amd64 (3.7.7+dfsg1-2build5) ...
# Selecting previously unselected package libparpack2-dev:amd64.
# Preparing to unpack .../56-libparpack2-dev_3.5.0+real-2_amd64.deb ...
# Unpacking libparpack2-dev:amd64 (3.5.0+real-2) ...
# Selecting previously unselected package libslepc3.7.4-dev.
# Preparing to unpack .../57-libslepc3.7.4-dev_3.7.4+dfsg1-2build8_amd64.deb ...
# Unpacking libslepc3.7.4-dev (3.7.4+dfsg1-2build8) ...
# Selecting previously unselected package libdolfin-dev:amd64.
# Preparing to unpack .../58-libdolfin-dev_2019.2.0~git20201207.b495043-4~ppa1~bionic6_amd64.deb ...
# Unpacking libdolfin-dev:amd64 (2019.2.0~git20201207.b495043-4~ppa1~bionic6) ...
# Selecting previously unselected package python3-petsc4py.
# Preparing to unpack .../59-python3-petsc4py_3.7.0-3build2_amd64.deb ...
# Unpacking python3-petsc4py (3.7.0-3build2) ...
# Selecting previously unselected package python3-slepc4py.
# Preparing to unpack .../60-python3-slepc4py_3.7.0-3build1_amd64.deb ...
# Unpacking python3-slepc4py (3.7.0-3build1) ...
# Selecting previously unselected package python3-dolfin-real.
# Preparing to unpack .../61-python3-dolfin-real_2019.2.0~git20201207.b495043-4~ppa1~bionic6_amd64.deb ...
# Unpacking python3-dolfin-real (2019.2.0~git20201207.b495043-4~ppa1~bionic6) ...
# Selecting previously unselected package python3-ply.
# Preparing to unpack .../62-python3-ply_3.11-1_all.deb ...
# Unpacking python3-ply (3.11-1) ...
# Selecting previously unselected package pybind11-dev.
# Preparing to unpack .../63-pybind11-dev_2.2.3-1fenics1bionic1_all.deb ...
# Unpacking pybind11-dev (2.2.3-1fenics1bionic1) ...
# Selecting previously unselected package python3-pybind11.
# Preparing to unpack .../64-python3-pybind11_2.2.3-1fenics1bionic1_all.deb ...
# Unpacking python3-pybind11 (2.2.3-1fenics1bionic1) ...
# Selecting previously unselected package python3-six.
# Preparing to unpack .../65-python3-six_1.11.0-2_all.deb ...
# Unpacking python3-six (1.11.0-2) ...
# Selecting previously unselected package python3-pkgconfig.
# Preparing to unpack .../66-python3-pkgconfig_1.3.1-1_all.deb ...
# Unpacking python3-pkgconfig (1.3.1-1) ...
# Selecting previously unselected package python3-dolfin.
# Preparing to unpack .../67-python3-dolfin_2019.2.0~git20201207.b495043-4~ppa1~bionic6_amd64.deb ...
# Unpacking python3-dolfin (2019.2.0~git20201207.b495043-4~ppa1~bionic6) ...
# Selecting previously unselected package dolfin-bin.
# Preparing to unpack .../68-dolfin-bin_2019.2.0~git20201207.b495043-4~ppa1~bionic6_all.deb ...
# Unpacking dolfin-bin (2019.2.0~git20201207.b495043-4~ppa1~bionic6) ...
# Selecting previously unselected package libjs-jquery.
# Preparing to unpack .../69-libjs-jquery_3.2.1-1_all.deb ...
# Unpacking libjs-jquery (3.2.1-1) ...
# Selecting previously unselected package libjs-underscore.
# Preparing to unpack .../70-libjs-underscore_1.8.3~dfsg-1ubuntu0.1_all.deb ...
# Unpacking libjs-underscore (1.8.3~dfsg-1ubuntu0.1) ...
# Selecting previously unselected package libjs-sphinxdoc.
# Preparing to unpack .../71-libjs-sphinxdoc_1.6.7-1ubuntu1_all.deb ...
# Unpacking libjs-sphinxdoc (1.6.7-1ubuntu1) ...
# Selecting previously unselected package fonts-font-awesome.
# Preparing to unpack .../72-fonts-font-awesome_4.7.0~dfsg-3_all.deb ...
# Unpacking fonts-font-awesome (4.7.0~dfsg-3) ...
# Selecting previously unselected package libjs-modernizr.
# Preparing to unpack .../73-libjs-modernizr_2.6.2+ds1-1ubuntu1_all.deb ...
# Unpacking libjs-modernizr (2.6.2+ds1-1ubuntu1) ...
# Selecting previously unselected package sphinx-rtd-theme-common.
# Preparing to unpack .../74-sphinx-rtd-theme-common_0.2.4-1_all.deb ...
# Unpacking sphinx-rtd-theme-common (0.2.4-1) ...
# Selecting previously unselected package dolfin-doc.
# Preparing to unpack .../75-dolfin-doc_2019.2.0~git20201207.b495043-4~ppa1~bionic6_all.deb ...
# Unpacking dolfin-doc (2019.2.0~git20201207.b495043-4~ppa1~bionic6) ...
# Selecting previously unselected package python-ufl-doc.
# Preparing to unpack .../76-python-ufl-doc_2019.2.0~git20210211.d60cd09-1~ppa1~bionic1_all.deb ...
# Unpacking python-ufl-doc (2019.2.0~git20210211.d60cd09-1~ppa1~bionic1) ...
# Selecting previously unselected package libtet1.5:amd64.
# Preparing to unpack .../77-libtet1.5_1.5.0-4_amd64.deb ...
# Unpacking libtet1.5:amd64 (1.5.0-4) ...
# Selecting previously unselected package libmshr2019.2:amd64.
# Preparing to unpack .../78-libmshr2019.2_2019.2.0~git20200924.c27eb18+git1-2~ppa1~bionic4_amd64.deb ...
# Unpacking libmshr2019.2:amd64 (2019.2.0~git20200924.c27eb18+git1-2~ppa1~bionic4) ...
# Selecting previously unselected package libmshr-dev-common:amd64.
# Preparing to unpack .../79-libmshr-dev-common_2019.2.0~git20200924.c27eb18+git1-2~ppa1~bionic4_amd64.deb ...
# Unpacking libmshr-dev-common:amd64 (2019.2.0~git20200924.c27eb18+git1-2~ppa1~bionic4) ...
# Selecting previously unselected package libmshr-dev.
# Preparing to unpack .../80-libmshr-dev_2019.2.0~git20200924.c27eb18+git1-2~ppa1~bionic4_amd64.deb ...
# Unpacking libmshr-dev (2019.2.0~git20200924.c27eb18+git1-2~ppa1~bionic4) ...
# Selecting previously unselected package python3-mshr-real.
# Preparing to unpack .../81-python3-mshr-real_2019.2.0~git20200924.c27eb18+git1-2~ppa1~bionic4_amd64.deb ...
# Unpacking python3-mshr-real (2019.2.0~git20200924.c27eb18+git1-2~ppa1~bionic4) ...
# Selecting previously unselected package python3-mshr.
# Preparing to unpack .../82-python3-mshr_2019.2.0~git20200924.c27eb18+git1-2~ppa1~bionic4_all.deb ...
# Unpacking python3-mshr (2019.2.0~git20200924.c27eb18+git1-2~ppa1~bionic4) ...
# Selecting previously unselected package fenics:amd64.
# Preparing to unpack .../83-fenics_1%3a2019.2.0.5~ppa1~bionic1_amd64.deb ...
# Unpacking fenics:amd64 (1:2019.2.0.5~ppa1~bionic1) ...
# Setting up python3-pkgconfig (1.3.1-1) ...
# Error processing line 3 of /usr/lib/python3/dist-packages/mshr.pth:
#
#   Traceback (most recent call last):
#     File "/usr/lib/python3.7/site.py", line 174, in addpackage
#       exec(line)
#     File "<string>", line 1, in <module>
#   FileNotFoundError: [Errno 2] No such file or directory: '/usr/lib/petsc/include/petscconf.h'
#
# Remainder of file ignored
# Error processing line 3 of /usr/lib/python3/dist-packages/mshr.pth:
#
#   Traceback (most recent call last):
#     File "/usr/lib/python3.6/site.py", line 174, in addpackage
#       exec(line)
#     File "<string>", line 1, in <module>
#   FileNotFoundError: [Errno 2] No such file or directory: '/usr/lib/petsc/include/petscconf.h'
#
# Remainder of file ignored
# Setting up libbtf1:amd64 (1:5.1.2-2) ...
# Setting up libldl2:amd64 (1:5.1.2-2) ...
# Setting up libjs-jquery (3.2.1-1) ...
# Setting up libscotch-6.0 (6.0.4.dfsg1-8) ...
# Setting up libcxsparse3:amd64 (1:5.1.2-2) ...
# Setting up python-ufl-doc (2019.2.0~git20210211.d60cd09-1~ppa1~bionic1) ...
# Setting up libjs-underscore (1.8.3~dfsg-1ubuntu0.1) ...
# Setting up libdolfin-dev-common (2019.2.0~git20201207.b495043-4~ppa1~bionic6) ...
# Setting up libtet1.5:amd64 (1.5.0-4) ...
# Setting up libscalapack-openmpi2.0 (2.0.2-4) ...
# Setting up libeigen3-dev (3.3.4-4) ...
# Setting up python3-numpy (1:1.13.3-2ubuntu1) ...
# Error processing line 3 of /usr/lib/python3/dist-packages/mshr.pth:
#
#   Traceback (most recent call last):
#     File "/usr/lib/python3.7/site.py", line 174, in addpackage
#       exec(line)
#     File "<string>", line 1, in <module>
#   FileNotFoundError: [Errno 2] No such file or directory: '/usr/lib/petsc/include/petscconf.h'
#
# Remainder of file ignored
# Error processing line 3 of /usr/lib/python3/dist-packages/mshr.pth:
#
#   Traceback (most recent call last):
#     File "/usr/lib/python3.6/site.py", line 174, in addpackage
#       exec(line)
#     File "<string>", line 1, in <module>
#   FileNotFoundError: [Errno 2] No such file or directory: '/usr/lib/petsc/include/petscconf.h'
#
# Remainder of file ignored
# Setting up libgraphblas1:amd64 (1:5.1.2-2) ...
# Setting up python3-six (1.11.0-2) ...
# Error processing line 3 of /usr/lib/python3/dist-packages/mshr.pth:
#
#   Traceback (most recent call last):
#     File "/usr/lib/python3.7/site.py", line 174, in addpackage
#       exec(line)
#     File "<string>", line 1, in <module>
#   FileNotFoundError: [Errno 2] No such file or directory: '/usr/lib/petsc/include/petscconf.h'
#
# Remainder of file ignored
# Error processing line 3 of /usr/lib/python3/dist-packages/mshr.pth:
#
#   Traceback (most recent call last):
#     File "/usr/lib/python3.6/site.py", line 174, in addpackage
#       exec(line)
#     File "<string>", line 1, in <module>
#   FileNotFoundError: [Errno 2] No such file or directory: '/usr/lib/petsc/include/petscconf.h'
#
# Remainder of file ignored
# Setting up libptscotch-6.0 (6.0.4.dfsg1-8) ...
# Setting up libparpack2:amd64 (3.5.0+real-2) ...
# Setting up libjs-sphinxdoc (1.6.7-1ubuntu1) ...
# Setting up libspooles2.2:amd64 (2.2-12build1) ...
# Setting up python3-pkg-resources (39.0.1-2) ...
# Error processing line 3 of /usr/lib/python3/dist-packages/mshr.pth:
#
#   Traceback (most recent call last):
#     File "/usr/lib/python3.7/site.py", line 174, in addpackage
#       exec(line)
#     File "<string>", line 1, in <module>
#   FileNotFoundError: [Errno 2] No such file or directory: '/usr/lib/petsc/include/petscconf.h'
#
# Remainder of file ignored
# Error processing line 3 of /usr/lib/python3/dist-packages/mshr.pth:
#
#   Traceback (most recent call last):
#     File "/usr/lib/python3.6/site.py", line 174, in addpackage
#       exec(line)
#     File "<string>", line 1, in <module>
#   FileNotFoundError: [Errno 2] No such file or directory: '/usr/lib/petsc/include/petscconf.h'
#
# Remainder of file ignored
# Setting up python3-mpmath (1.0.0-1) ...
# Error processing line 3 of /usr/lib/python3/dist-packages/mshr.pth:
#
#   Traceback (most recent call last):
#     File "/usr/lib/python3.7/site.py", line 174, in addpackage
#       exec(line)
#     File "<string>", line 1, in <module>
#   FileNotFoundError: [Errno 2] No such file or directory: '/usr/lib/petsc/include/petscconf.h'
#
# Remainder of file ignored
# Error processing line 3 of /usr/lib/python3/dist-packages/mshr.pth:
#
#   Traceback (most recent call last):
#     File "/usr/lib/python3.6/site.py", line 174, in addpackage
#       exec(line)
#     File "<string>", line 1, in <module>
#   FileNotFoundError: [Errno 2] No such file or directory: '/usr/lib/petsc/include/petscconf.h'
#
# Remainder of file ignored
# Setting up python3-ufl (2019.2.0~git20210211.d60cd09-1~ppa1~bionic1) ...
# Error processing line 3 of /usr/lib/python3/dist-packages/mshr.pth:
#
#   Traceback (most recent call last):
#     File "/usr/lib/python3.7/site.py", line 174, in addpackage
#       exec(line)
#     File "<string>", line 1, in <module>
#   FileNotFoundError: [Errno 2] No such file or directory: '/usr/lib/petsc/include/petscconf.h'
#
# Remainder of file ignored
# Error processing line 3 of /usr/lib/python3/dist-packages/mshr.pth:
#
#   Traceback (most recent call last):
#     File "/usr/lib/python3.6/site.py", line 174, in addpackage
#       exec(line)
#     File "<string>", line 1, in <module>
#   FileNotFoundError: [Errno 2] No such file or directory: '/usr/lib/petsc/include/petscconf.h'
#
# Remainder of file ignored
# Setting up fonts-font-awesome (4.7.0~dfsg-3) ...
# Setting up libscalapack-openmpi-dev (2.0.2-4) ...
# Setting up fonts-lato (2.0-2) ...
# Setting up libhdf5-openmpi-dev (1.10.0-patch1+docs-4) ...
# update-alternatives: using /usr/bin/h5pcc.openmpi to provide /usr/bin/h5pcc (h5pcc) in auto mode
# Setting up libfftw3-quad3:amd64 (3.3.7-1) ...
# Setting up libscotch-dev (6.0.4.dfsg1-8) ...
# Setting up libsuperlu-dist5 (5.3.0+dfsg1-1) ...
# Setting up libsuitesparseconfig5:amd64 (1:5.1.2-2) ...
# Setting up libmetis5:amd64 (5.1.0.dfsg-5) ...
# Setting up pybind11-dev (2.2.3-1fenics1bionic1) ...
# Setting up libcolamd2:amd64 (1:5.1.2-2) ...
# Setting up libccolamd2:amd64 (1:5.1.2-2) ...
# Setting up libfftw3-single3:amd64 (3.3.7-1) ...
# Setting up python3-mpi4py (2.0.0-3) ...
# Error processing line 3 of /usr/lib/python3/dist-packages/mshr.pth:
#
#   Traceback (most recent call last):
#     File "/usr/lib/python3.7/site.py", line 174, in addpackage
#       exec(line)
#     File "<string>", line 1, in <module>
#   FileNotFoundError: [Errno 2] No such file or directory: '/usr/lib/petsc/include/petscconf.h'
#
# Remainder of file ignored
# Error processing line 3 of /usr/lib/python3/dist-packages/mshr.pth:
#
#   Traceback (most recent call last):
#     File "/usr/lib/python3.6/site.py", line 174, in addpackage
#       exec(line)
#     File "<string>", line 1, in <module>
#   FileNotFoundError: [Errno 2] No such file or directory: '/usr/lib/petsc/include/petscconf.h'
#
# Remainder of file ignored
# Setting up python3-ply (3.11-1) ...
# Error processing line 3 of /usr/lib/python3/dist-packages/mshr.pth:
#
#   Traceback (most recent call last):
#     File "/usr/lib/python3.7/site.py", line 174, in addpackage
#       exec(line)
#     File "<string>", line 1, in <module>
#   FileNotFoundError: [Errno 2] No such file or directory: '/usr/lib/petsc/include/petscconf.h'
#
# Remainder of file ignored
# Error processing line 3 of /usr/lib/python3/dist-packages/mshr.pth:
#
#   Traceback (most recent call last):
#     File "/usr/lib/python3.6/site.py", line 174, in addpackage
#       exec(line)
#     File "<string>", line 1, in <module>
#   FileNotFoundError: [Errno 2] No such file or directory: '/usr/lib/petsc/include/petscconf.h'
#
# Remainder of file ignored
# Setting up python3-sympy (1.1.1-5) ...
# Error processing line 3 of /usr/lib/python3/dist-packages/mshr.pth:
#
#   Traceback (most recent call last):
#     File "/usr/lib/python3.7/site.py", line 174, in addpackage
#       exec(line)
#     File "<string>", line 1, in <module>
#   FileNotFoundError: [Errno 2] No such file or directory: '/usr/lib/petsc/include/petscconf.h'
#
# Remainder of file ignored
# Error processing line 3 of /usr/lib/python3/dist-packages/mshr.pth:
#
#   Traceback (most recent call last):
#     File "/usr/lib/python3.6/site.py", line 174, in addpackage
#       exec(line)
#     File "<string>", line 1, in <module>
#   FileNotFoundError: [Errno 2] No such file or directory: '/usr/lib/petsc/include/petscconf.h'
#
# Remainder of file ignored
# Setting up libspooles-dev:amd64 (2.2-12build1) ...
# Setting up libfftw3-long3:amd64 (3.3.7-1) ...
# Setting up libjs-modernizr (2.6.2+ds1-1ubuntu1) ...
# Setting up python3-pybind11 (2.2.3-1fenics1bionic1) ...
# Error processing line 3 of /usr/lib/python3/dist-packages/mshr.pth:
#
#   Traceback (most recent call last):
#     File "/usr/lib/python3.7/site.py", line 174, in addpackage
#       exec(line)
#     File "<string>", line 1, in <module>
#   FileNotFoundError: [Errno 2] No such file or directory: '/usr/lib/petsc/include/petscconf.h'
#
# Remainder of file ignored
# Error processing line 3 of /usr/lib/python3/dist-packages/mshr.pth:
#
#   Traceback (most recent call last):
#     File "/usr/lib/python3.6/site.py", line 174, in addpackage
#       exec(line)
#     File "<string>", line 1, in <module>
#   FileNotFoundError: [Errno 2] No such file or directory: '/usr/lib/petsc/include/petscconf.h'
#
# Remainder of file ignored
# Setting up python3-fiat (2019.2.0~git20210116.0439689-3~ppa1~bionic2) ...
# Error processing line 3 of /usr/lib/python3/dist-packages/mshr.pth:
#
#   Traceback (most recent call last):
#     File "/usr/lib/python3.7/site.py", line 174, in addpackage
#       exec(line)
#     File "<string>", line 1, in <module>
#   FileNotFoundError: [Errno 2] No such file or directory: '/usr/lib/petsc/include/petscconf.h'
#
# Remainder of file ignored
# Error processing line 3 of /usr/lib/python3/dist-packages/mshr.pth:
#
#   Traceback (most recent call last):
#     File "/usr/lib/python3.6/site.py", line 174, in addpackage
#       exec(line)
#     File "<string>", line 1, in <module>
#   FileNotFoundError: [Errno 2] No such file or directory: '/usr/lib/petsc/include/petscconf.h'
#
# Remainder of file ignored
# Setting up libparpack2-dev:amd64 (3.5.0+real-2) ...
# Setting up libfftw3-bin (3.3.7-1) ...
# Setting up libmumps-5.1.2:amd64 (5.1.2-4) ...
# Setting up libptscotch-dev (6.0.4.dfsg1-8) ...
# Setting up libscalapack-mpi-dev (2.0.2-4) ...
# Setting up libhypre-2.13.0:amd64 (2.13.0-2) ...
# Setting up librbio2:amd64 (1:5.1.2-2) ...
# Setting up libcamd2:amd64 (1:5.1.2-2) ...
# Setting up libfftw3-mpi3:amd64 (3.3.7-1) ...
# Setting up libmumps-dev:amd64 (5.1.2-4) ...
# Setting up python3-dijitso (2019.2.0~git20190418.c92dcb0-2~ppa1~bionic3) ...
# Error processing line 3 of /usr/lib/python3/dist-packages/mshr.pth:
#
#   Traceback (most recent call last):
#     File "/usr/lib/python3.7/site.py", line 174, in addpackage
#       exec(line)
#     File "<string>", line 1, in <module>
#   FileNotFoundError: [Errno 2] No such file or directory: '/usr/lib/petsc/include/petscconf.h'
#
# Remainder of file ignored
# Error processing line 3 of /usr/lib/python3/dist-packages/mshr.pth:
#
#   Traceback (most recent call last):
#     File "/usr/lib/python3.6/site.py", line 174, in addpackage
#       exec(line)
#     File "<string>", line 1, in <module>
#   FileNotFoundError: [Errno 2] No such file or directory: '/usr/lib/petsc/include/petscconf.h'
#
# Remainder of file ignored
# Setting up libhdf5-mpi-dev (1.10.0-patch1+docs-4) ...
# Setting up libamd2:amd64 (1:5.1.2-2) ...
# Setting up sphinx-rtd-theme-common (0.2.4-1) ...
# Setting up libfftw3-dev:amd64 (3.3.7-1) ...
# Setting up python3-ffc (2019.2.0~git20210115.cb26c91-1~ppa1~bionic1) ...
# Error processing line 3 of /usr/lib/python3/dist-packages/mshr.pth:
#
#   Traceback (most recent call last):
#     File "/usr/lib/python3.7/site.py", line 174, in addpackage
#       exec(line)
#     File "<string>", line 1, in <module>
#   FileNotFoundError: [Errno 2] No such file or directory: '/usr/lib/petsc/include/petscconf.h'
#
# Remainder of file ignored
# Error processing line 3 of /usr/lib/python3/dist-packages/mshr.pth:
#
#   Traceback (most recent call last):
#     File "/usr/lib/python3.6/site.py", line 174, in addpackage
#       exec(line)
#     File "<string>", line 1, in <module>
#   FileNotFoundError: [Errno 2] No such file or directory: '/usr/lib/petsc/include/petscconf.h'
#
# Remainder of file ignored
# Setting up libfftw3-mpi-dev:amd64 (3.3.7-1) ...
# Setting up libhypre-dev:amd64 (2.13.0-2) ...
# Setting up libmshr-dev-common:amd64 (2019.2.0~git20200924.c27eb18+git1-2~ppa1~bionic4) ...
# Setting up libklu1:amd64 (1:5.1.2-2) ...
# Setting up libcholmod3:amd64 (1:5.1.2-2) ...
# Setting up libspqr2:amd64 (1:5.1.2-2) ...
# Setting up libumfpack5:amd64 (1:5.1.2-2) ...
# Setting up libpetsc3.7.7:amd64 (3.7.7+dfsg1-2build5) ...
# update-alternatives: using /usr/lib/x86_64-linux-gnu/libpetsc_real.so.3.7.7 to provide /usr/lib/x86_64-linux-gnu/libpetsc.so.3.7 (libpetsc.so.3.7) in auto mode
# update-alternatives: using /usr/lib/x86_64-linux-gnu/libpetsc_real.so.3.7.7 to provide /usr/lib/x86_64-linux-gnu/libpetsc_real.so.3.7 (libpetsc_real.so.3.7) in auto mode
# Setting up python3-petsc4py (3.7.0-3build2) ...
# Error processing line 3 of /usr/lib/python3/dist-packages/mshr.pth:
#
#   Traceback (most recent call last):
#     File "/usr/lib/python3.7/site.py", line 174, in addpackage
#       exec(line)
#     File "<string>", line 1, in <module>
#   FileNotFoundError: [Errno 2] No such file or directory: '/usr/lib/petsc/include/petscconf.h'
#
# Remainder of file ignored
# Error processing line 3 of /usr/lib/python3/dist-packages/mshr.pth:
#
#   Traceback (most recent call last):
#     File "/usr/lib/python3.6/site.py", line 174, in addpackage
#       exec(line)
#     File "<string>", line 1, in <module>
#   FileNotFoundError: [Errno 2] No such file or directory: '/usr/lib/petsc/include/petscconf.h'
#
# Remainder of file ignored
# Setting up libsuitesparse-dev:amd64 (1:5.1.2-2) ...
# Setting up libpetsc3.7.7-dev:amd64 (3.7.7+dfsg1-2build5) ...
# update-alternatives: error: no alternatives for petsc
# update-alternatives: using /usr/lib/petscdir/3.7.7/x86_64-linux-gnu-real to provide /usr/lib/petsc (petsc) in auto mode
# update-alternatives: using /usr/lib/x86_64-linux-gnu/libpetsc_real.so.3.7.7 to provide /usr/lib/x86_64-linux-gnu/libpetsc_real.so (libpetsc_real.so) in auto mode
# update-alternatives: using /usr/lib/petscdir/3.7.7/x86_64-linux-gnu-real to provide /usr/lib/petscdir/3.7 (petsc3.7) in auto mode
# update-alternatives: using /usr/lib/petscdir/3.7.7/x86_64-linux-gnu-real to provide /usr/lib/petscdir/3.7-real (petsc3.7-real) in auto mode
# Setting up libslepc3.7.4 (3.7.4+dfsg1-2build8) ...
# update-alternatives: using /usr/lib/x86_64-linux-gnu/libslepc_real.so.3.7.4 to provide /usr/lib/x86_64-linux-gnu/libslepc.so.3.7 (libslepc.so.3.7) in auto mode
# update-alternatives: using /usr/lib/x86_64-linux-gnu/libslepc_real.so.3.7.4 to provide /usr/lib/x86_64-linux-gnu/libslepc_real.so.3.7 (libslepc_real.so.3.7) in auto mode
# Setting up python3-slepc4py (3.7.0-3build1) ...
# Setting up libslepc3.7.4-dev (3.7.4+dfsg1-2build8) ...
# update-alternatives: error: no alternatives for slepc
# update-alternatives: using /usr/lib/slepcdir/3.7.4/x86_64-linux-gnu-real to provide /usr/lib/slepc (slepc) in auto mode
# update-alternatives: using /usr/lib/x86_64-linux-gnu/libslepc_real.so.3.7.4 to provide /usr/lib/x86_64-linux-gnu/libslepc_real.so (libslepc_real.so) in auto mode
# update-alternatives: using /usr/lib/slepcdir/3.7.4/x86_64-linux-gnu-real to provide /usr/lib/slepcdir/3.7 (slepc3.7) in auto mode
# update-alternatives: using /usr/lib/slepcdir/3.7.4/x86_64-linux-gnu-real to provide /usr/lib/slepcdir/3.7-real (slepc3.7-real) in auto mode
# Setting up libdolfin2019.2:amd64 (2019.2.0~git20201207.b495043-4~ppa1~bionic6) ...
# Setting up libmshr2019.2:amd64 (2019.2.0~git20200924.c27eb18+git1-2~ppa1~bionic4) ...
# Setting up libdolfin-dev:amd64 (2019.2.0~git20201207.b495043-4~ppa1~bionic6) ...
# Setting up libmshr-dev (2019.2.0~git20200924.c27eb18+git1-2~ppa1~bionic4) ...
# Setting up python3-dolfin-real (2019.2.0~git20201207.b495043-4~ppa1~bionic6) ...
# Setting up python3-dolfin (2019.2.0~git20201207.b495043-4~ppa1~bionic6) ...
# Setting up dolfin-doc (2019.2.0~git20201207.b495043-4~ppa1~bionic6) ...
# Setting up dolfin-bin (2019.2.0~git20201207.b495043-4~ppa1~bionic6) ...
# Setting up python3-mshr-real (2019.2.0~git20200924.c27eb18+git1-2~ppa1~bionic4) ...
# Setting up python3-mshr (2019.2.0~git20200924.c27eb18+git1-2~ppa1~bionic4) ...
# Setting up fenics:amd64 (1:2019.2.0.5~ppa1~bionic1) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# Processing triggers for fontconfig (2.12.6-0ubuntu2) ...
# Processing triggers for libc-bin (2.27-3ubuntu1.2) ...
# /sbin/ldconfig.real: /usr/local/lib/python3.7/dist-packages/ideep4py/lib/libmkldnn.so.0 is not a symbolic link
#
# --2021-06-17 08:02:25--  https://drive.google.com/uc?export=download&id=1cT_QBJCOW_eL3BThnval3bcpb8o0w-Ad
# Resolving drive.google.com (drive.google.com)... 142.251.2.100, 142.251.2.113, 142.251.2.101, ...
# Connecting to drive.google.com (drive.google.com)|142.251.2.100|:443... connected.
# HTTP request sent, awaiting response... 302 Moved Temporarily
# Location: https://doc-0s-2c-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/dnm8cdasf0ob7u3ujpl0bc5q83rve29k/1623916875000/12075201528694079695/*/1cT_QBJCOW_eL3BThnval3bcpb8o0w-Ad?e=download [following]
# Warning: wildcards not supported in HTTP.
# --2021-06-17 08:02:26--  https://doc-0s-2c-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/dnm8cdasf0ob7u3ujpl0bc5q83rve29k/1623916875000/12075201528694079695/*/1cT_QBJCOW_eL3BThnval3bcpb8o0w-Ad?e=download
# Resolving doc-0s-2c-docs.googleusercontent.com (doc-0s-2c-docs.googleusercontent.com)... 74.125.137.132, 2607:f8b0:4023:c03::84
# Connecting to doc-0s-2c-docs.googleusercontent.com (doc-0s-2c-docs.googleusercontent.com)|74.125.137.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2012751 (1.9M) [application/x-zip]
# Saving to: ‘/tmp/mpi4py-2.0.0-cp37-cp37m-linux_x86_64.whl’
#
# /tmp/mpi4py-2.0.0-c 100%[===================>]   1.92M  11.4MB/s    in 0.2s
#
# 2021-06-17 08:02:26 (11.4 MB/s) - ‘/tmp/mpi4py-2.0.0-cp37-cp37m-linux_x86_64.whl’ saved [2012751/2012751]
#
# --2021-06-17 08:02:26--  https://drive.google.com/uc?export=download&id=119i49bxlGn1mrnhTNmOvM4BqmjrT9Ppr
# Resolving drive.google.com (drive.google.com)... 142.251.2.100, 142.251.2.138, 142.251.2.113, ...
# Connecting to drive.google.com (drive.google.com)|142.251.2.100|:443... connected.
# HTTP request sent, awaiting response... 302 Moved Temporarily
# Location: https://doc-0g-2c-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/ngq7es8ob92fpualv0c4ttet840i532q/1623916875000/12075201528694079695/*/119i49bxlGn1mrnhTNmOvM4BqmjrT9Ppr?e=download [following]
# Warning: wildcards not supported in HTTP.
# --2021-06-17 08:02:27--  https://doc-0g-2c-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/ngq7es8ob92fpualv0c4ttet840i532q/1623916875000/12075201528694079695/*/119i49bxlGn1mrnhTNmOvM4BqmjrT9Ppr?e=download
# Resolving doc-0g-2c-docs.googleusercontent.com (doc-0g-2c-docs.googleusercontent.com)... 74.125.137.132, 2607:f8b0:4023:c03::84
# Connecting to doc-0g-2c-docs.googleusercontent.com (doc-0g-2c-docs.googleusercontent.com)|74.125.137.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/x-zip]
# Saving to: ‘/tmp/petsc4py-3.7.0-cp37-cp37m-linux_x86_64.whl’
#
# /tmp/petsc4py-3.7.0     [  <=>               ]   3.93M  18.8MB/s    in 0.2s
#
# 2021-06-17 08:02:27 (18.8 MB/s) - ‘/tmp/petsc4py-3.7.0-cp37-cp37m-linux_x86_64.whl’ saved [4121270]
#
# --2021-06-17 08:02:28--  https://drive.google.com/uc?export=download&id=1-1tVfu8qz3bRC2zvR8n3RESpesWqNnn6
# Resolving drive.google.com (drive.google.com)... 142.251.2.100, 142.251.2.138, 142.251.2.113, ...
# Connecting to drive.google.com (drive.google.com)|142.251.2.100|:443... connected.
# HTTP request sent, awaiting response... 302 Moved Temporarily
# Location: https://doc-04-2c-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/s71v0fflgv79b5ft1nd0g4bjs97j3b36/1623916950000/12075201528694079695/*/1-1tVfu8qz3bRC2zvR8n3RESpesWqNnn6?e=download [following]
# Warning: wildcards not supported in HTTP.
# --2021-06-17 08:02:30--  https://doc-04-2c-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/s71v0fflgv79b5ft1nd0g4bjs97j3b36/1623916950000/12075201528694079695/*/1-1tVfu8qz3bRC2zvR8n3RESpesWqNnn6?e=download
# Resolving doc-04-2c-docs.googleusercontent.com (doc-04-2c-docs.googleusercontent.com)... 74.125.137.132, 2607:f8b0:4023:c03::84
# Connecting to doc-04-2c-docs.googleusercontent.com (doc-04-2c-docs.googleusercontent.com)|74.125.137.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 942194 (920K) [application/x-zip]
# Saving to: ‘/tmp/slepc4py-3.7.0-cp37-cp37m-linux_x86_64.whl’
#
# /tmp/slepc4py-3.7.0 100%[===================>] 920.11K  5.92MB/s    in 0.2s
#
# 2021-06-17 08:02:30 (5.92 MB/s) - ‘/tmp/slepc4py-3.7.0-cp37-cp37m-linux_x86_64.whl’ saved [942194/942194]
#
# --2021-06-17 08:02:30--  https://drive.google.com/uc?export=download&id=1-3qY4VIJQaXVO1HfGQIzTIURIeJbvX-9
# Resolving drive.google.com (drive.google.com)... 142.251.2.100, 142.251.2.138, 142.251.2.113, ...
# Connecting to drive.google.com (drive.google.com)|142.251.2.100|:443... connected.
# HTTP request sent, awaiting response... 302 Moved Temporarily
# Location: https://doc-08-2c-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/eo39dfhe4t0v0jos332jkoqa37j9qfj4/1623916950000/12075201528694079695/*/1-3qY4VIJQaXVO1HfGQIzTIURIeJbvX-9?e=download [following]
# Warning: wildcards not supported in HTTP.
# --2021-06-17 08:02:31--  https://doc-08-2c-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/eo39dfhe4t0v0jos332jkoqa37j9qfj4/1623916950000/12075201528694079695/*/1-3qY4VIJQaXVO1HfGQIzTIURIeJbvX-9?e=download
# Resolving doc-08-2c-docs.googleusercontent.com (doc-08-2c-docs.googleusercontent.com)... 74.125.137.132, 2607:f8b0:4023:c03::84
# Connecting to doc-08-2c-docs.googleusercontent.com (doc-08-2c-docs.googleusercontent.com)|74.125.137.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1082607 (1.0M) [application/x-zip]
# Saving to: ‘/tmp/fenics_dolfin-2019.2.0.dev0-cp37-cp37m-linux_x86_64.whl’
#
# /tmp/fenics_dolfin- 100%[===================>]   1.03M  6.31MB/s    in 0.2s
#
# 2021-06-17 08:02:32 (6.31 MB/s) - ‘/tmp/fenics_dolfin-2019.2.0.dev0-cp37-cp37m-linux_x86_64.whl’ saved [1082607/1082607]
#
# --2021-06-17 08:02:32--  https://drive.google.com/uc?export=download&id=1-5SMjgjMuee_9WLeYtGe8N_lvipWEN7W
# Resolving drive.google.com (drive.google.com)... 142.251.2.100, 142.251.2.113, 142.251.2.101, ...
# Connecting to drive.google.com (drive.google.com)|142.251.2.100|:443... connected.
# HTTP request sent, awaiting response... 302 Moved Temporarily
# Location: https://doc-0o-2c-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/3go28i1mhnqmmrfkpfftp4hjrr9aa9jh/1623916950000/12075201528694079695/*/1-5SMjgjMuee_9WLeYtGe8N_lvipWEN7W?e=download [following]
# Warning: wildcards not supported in HTTP.
# --2021-06-17 08:02:32--  https://doc-0o-2c-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/3go28i1mhnqmmrfkpfftp4hjrr9aa9jh/1623916950000/12075201528694079695/*/1-5SMjgjMuee_9WLeYtGe8N_lvipWEN7W?e=download
# Resolving doc-0o-2c-docs.googleusercontent.com (doc-0o-2c-docs.googleusercontent.com)... 74.125.137.132, 2607:f8b0:4023:c03::84
# Connecting to doc-0o-2c-docs.googleusercontent.com (doc-0o-2c-docs.googleusercontent.com)|74.125.137.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1267413 (1.2M) [application/x-zip]
# Saving to: ‘/tmp/mshr-2019.2.0.dev0-cp37-cp37m-linux_x86_64.whl’
#
# /tmp/mshr-2019.2.0. 100%[===================>]   1.21M  6.49MB/s    in 0.2s
#
# 2021-06-17 08:02:33 (6.49 MB/s) - ‘/tmp/mshr-2019.2.0.dev0-cp37-cp37m-linux_x86_64.whl’ saved [1267413/1267413]
#
# Processing /tmp/mpi4py-2.0.0-cp37-cp37m-linux_x86_64.whl
# Installing collected packages: mpi4py
# Successfully installed mpi4py-2.0.0
# Processing /tmp/petsc4py-3.7.0-cp37-cp37m-linux_x86_64.whl
# Requirement already satisfied, skipping upgrade: numpy in /usr/local/lib/python3.7/dist-packages (from petsc4py==3.7.0) (1.19.5)
# Installing collected packages: petsc4py
# Successfully installed petsc4py-3.7.0
# Processing /tmp/slepc4py-3.7.0-cp37-cp37m-linux_x86_64.whl
# Requirement already satisfied, skipping upgrade: petsc4py<3.8,>=3.7 in /usr/local/lib/python3.7/dist-packages (from slepc4py==3.7.0) (3.7.0)
# Requirement already satisfied, skipping upgrade: numpy in /usr/local/lib/python3.7/dist-packages (from petsc4py<3.8,>=3.7->slepc4py==3.7.0) (1.19.5)
# Installing collected packages: slepc4py
# Successfully installed slepc4py-3.7.0
# Processing /tmp/fenics_dolfin-2019.2.0.dev0-cp37-cp37m-linux_x86_64.whl
# Requirement already satisfied, skipping upgrade: fenics-dijitso<2019.3,>=2019.2.0.dev0 in /usr/lib/python3/dist-packages (from fenics-dolfin==2019.2.0.dev0) (2019.2.0.dev0)
# Requirement already satisfied, skipping upgrade: fenics-ufl<2019.3,>=2019.2.0.dev0 in /usr/lib/python3/dist-packages (from fenics-dolfin==2019.2.0.dev0) (2019.2.0.dev0)
# Requirement already satisfied, skipping upgrade: fenics-ffc<2019.3,>=2019.2.0.dev0 in /usr/lib/python3/dist-packages (from fenics-dolfin==2019.2.0.dev0) (2019.2.0.dev0)
# Requirement already satisfied, skipping upgrade: pkgconfig in /usr/lib/python3/dist-packages (from fenics-dolfin==2019.2.0.dev0) (1.3.1)
# Requirement already satisfied, skipping upgrade: numpy in /usr/local/lib/python3.7/dist-packages (from fenics-dolfin==2019.2.0.dev0) (1.19.5)
# Requirement already satisfied, skipping upgrade: pybind11 in /usr/lib/python3/dist-packages (from fenics-dolfin==2019.2.0.dev0) (2.2.3)
# Installing collected packages: fenics-dolfin
#   Found existing installation: fenics-dolfin 2019.2.0.dev0
#     Uninstalling fenics-dolfin-2019.2.0.dev0:
#       Successfully uninstalled fenics-dolfin-2019.2.0.dev0
# Successfully installed fenics-dolfin-2019.2.0.dev0
# Processing /tmp/mshr-2019.2.0.dev0-cp37-cp37m-linux_x86_64.whl
# Requirement already satisfied, skipping upgrade: fenics-dolfin in /usr/local/lib/python3.7/dist-packages (from mshr==2019.2.0.dev0) (2019.2.0.dev0)
# Requirement already satisfied, skipping upgrade: numpy in /usr/local/lib/python3.7/dist-packages (from mshr==2019.2.0.dev0) (1.19.5)
# Requirement already satisfied, skipping upgrade: fenics-ufl<2019.3,>=2019.2.0.dev0 in /usr/lib/python3/dist-packages (from fenics-dolfin->mshr==2019.2.0.dev0) (2019.2.0.dev0)
# Requirement already satisfied, skipping upgrade: fenics-ffc<2019.3,>=2019.2.0.dev0 in /usr/lib/python3/dist-packages (from fenics-dolfin->mshr==2019.2.0.dev0) (2019.2.0.dev0)
# Requirement already satisfied, skipping upgrade: pkgconfig in /usr/lib/python3/dist-packages (from fenics-dolfin->mshr==2019.2.0.dev0) (1.3.1)
# Requirement already satisfied, skipping upgrade: pybind11 in /usr/lib/python3/dist-packages (from fenics-dolfin->mshr==2019.2.0.dev0) (2.2.3)
# Requirement already satisfied, skipping upgrade: fenics-dijitso<2019.3,>=2019.2.0.dev0 in /usr/lib/python3/dist-packages (from fenics-dolfin->mshr==2019.2.0.dev0) (2019.2.0.dev0)
# Installing collected packages: mshr
#   Found existing installation: mshr 2019.2.0.dev0
#     Uninstalling mshr-2019.2.0.dev0:
#       Successfully uninstalled mshr-2019.2.0.dev0
# Successfully installed mshr-2019.2.0.dev0
#      |████████████████████████████████| 6.1MB 6.4MB/s
# Dolfin installation is done with version 2019.2.0.dev0

# %%
#Because we have a problem with version' compatibility we hae to re install h5py
# !pip3 uninstall -y h5py
# !pip3 install h5py
# Out:
# Uninstalling h5py-3.1.0:
#   Successfully uninstalled h5py-3.1.0
# Collecting h5py
#   Downloading https://files.pythonhosted.org/packages/b3/c5/94e2444eb691f658fb8e3cf6cde3ae29540cf6d9ce76f0561afcdbb89136/h5py-3.2.1-cp37-cp37m-manylinux1_x86_64.whl (4.1MB)
#      |████████████████████████████████| 4.1MB 7.5MB/s
# Requirement already satisfied: cached-property; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from h5py) (1.5.2)
# Requirement already satisfied: numpy>=1.14.5; python_version == "3.7" in /usr/local/lib/python3.7/dist-packages (from h5py) (1.19.5)
# ERROR: tensorflow 2.5.0 has requirement h5py~=3.1.0, but you'll have h5py 3.2.1 which is incompatible.
# Installing collected packages: h5py
# Successfully installed h5py-3.2.1

# %%
#We import:
import os, sys, shutil, meshio
import datetime
import h5py
import hdf5

print('la version de h5py :',h5py.__version__)
print('la version de hdf5 de c mort :',hdf5.__version__)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-6-136ed2d34576> in <module>()
#       3 import datetime
#       4 import h5py
# ----> 5 import hdf5
#       6
#       7 print('la version de h5py :',h5py.__version__)
#
# ModuleNotFoundError: No module named 'hdf5'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
import platform
print('Python version: ',platform.python_version())
# Out:
# Python version:  3.7.10

# %%
# !pip freeze > requirements.txt

# %% [markdown]
# # **2-Manage input data and external scripts**
# We stock data and results on Google Drive.

# %%
  from google.colab import drive
#sortir le # si drive déjà monté
drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     728             try:
# --> 729                 ident, reply = self.session.recv(self.stdin_socket, 0)
#     730             except Exception:
#
# /usr/local/lib/python3.7/dist-packages/jupyter_client/session.py in recv(self, socket, mode, content, copy)
#     802         try:
# --> 803             msg_list = socket.recv_multipart(mode, copy=copy)
#     804         except zmq.ZMQError as e:
#
# /usr/local/lib/python3.7/dist-packages/zmq/sugar/socket.py in recv_multipart(self, flags, copy, track)
#     582         """
# --> 583         parts = [self.recv(flags, copy=copy, track=track)]
#     584         # have first part already, only loop while more to receive
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.recv()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.recv()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket._recv_copy()
#
# /usr/local/lib/python3.7/dist-packages/zmq/backend/cython/checkrc.pxd in zmq.backend.cython.checkrc._check_rc()
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-dab1a18bbfa8> in <module>()
#       1 from google.colab import drive
#       2 #sortir le # si drive déjà monté
# ----> 3 drive.mount('/content/drive')
#
# /usr/local/lib/python3.7/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, use_metadata_server)
#     258       with _output.use_tags('dfs-auth-dance'):
#     259         with open(fifo, 'w') as fifo_file:
# --> 260           fifo_file.write(get_code(auth_prompt) + '\n')
#     261       wrote_to_fifo = True
#     262     elif case == 5:
#
# /usr/local/lib/python3.7/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     702             self._parent_ident,
#     703             self._parent_header,
# --> 704             password=False,
#     705         )
#     706
#
# /usr/local/lib/python3.7/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     732             except KeyboardInterrupt:
#     733                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 734                 raise KeyboardInterrupt
#     735             else:
#     736                 break
#
# KeyboardInterrupt:

# %% [markdown]
# We need to import "msh2xdmf.py" in order to convert *.msh* files for FEniCS utilsation.

# %%
#We import msh2xdmf.py file which is on our local machine.
from google.colab import files

uploaded = files.upload()

print("Importation successfully")

# %% [markdown]
# # **3-Inherent Strain**
# We begin by definning the Inherent Strain function.
# The function is split in 3 parts:
# - 1) Converting *.msh* for FEniCS
# - 2) Boundary condition
# - 3) Defining the IS function
#
# In addition, we have also to define the work environment and create results files.

# %%
'''
THIS BLOCK contains the inherent Strain:
'''

import os
import meshio
from msh2xdmf import msh2xdmf, import_mesh_from_xdmf
from dolfin import *
import numpy as np

 
def InherentStrain(in_folder,piece,out_folder,param):

  # -------------------- #
  #   Import mesh files  #
  # -------------------- #

  print('Converting',piece)
  #Transform mesh into fenics format
  msh2xdmf(piece, dim=3, directory=in_folder)
  # Run the import:
  mesh, boundaries, subdomains, labels = import_mesh_from_xdmf(
      prefix=str_name,
      dim=3,
      directory=in_folder,
      subdomains=True,
      )
  la=meshio.read(in_folder+'/'+piece)
  print('We can import the mesh, look: \n',mesh, 'and the dimension of the mesh is:',mesh.geometry().dim())
 

  # ------------------------- #
  #   Define the environment  #
  # ------------------------- #

  #Finite Element space definitions: the vector and the tensor function space
  V = VectorFunctionSpace(mesh, 'P', 1) #we put 1 to stop translation and rotation
  T = TensorFunctionSpace(mesh, 'DG', 0) #Discontinuous Lagrange 
  tol= 1E-14 # tolerance



  # -------------------- #
  #   Create boundaries  #
  # -------------------- #
  
  class BoundaryBottom_func(SubDomain):
    def inside(self, x, on_boundary):
      #x[2] is z axe, fixing bottom surface. 
      # return on_boundary and near(x[2], 2., tol) #no fix bottom regarde si on peut pas mettre une petite distance
      return on_boundary and x[2] <= 0.0 #fix bottom surface / Before cutting / We fix everything that is 0< or =0
      #return on_boundary and x[0] <=10.0 and x[1] <= 12.0 #partie massive fixe
    
  
  BoundaryBottom = BoundaryBottom_func() 

  #Set markers as 1 at bottom surface (for visualisation in para view)
  BoundaryMarker = MeshFunction("size_t", mesh, mesh.topology().dim() - 1) 

  BoundaryMarker = MeshFunction('size_t', mesh,dim=3)

  BoundaryMarker.set_all(0)
  BoundaryBottom.mark(BoundaryMarker, 1)

  #Dirichlet meaning: the values that a solution needs to take along the boundary of the domain. 
  bc = DirichletBC(V,
                   Constant((0.,0.,0.)),
                   BoundaryBottom)


  # ---------------- #
  #  Material param  #
  # ---------------- #

  #The material is : IN-718_powder 

  E = 191000  #Young's modulus (MPa) 
  nu = 0.31   #Poisson's ratio

  #Some constant
  lmbda = E*nu/((1.0 + nu)*(1.0 - 2.0*nu)) #first Lamé coefficient 
  mu = E/(2.0*(1.0 + nu)) #shear modulus


  # ---------------------------- #
  #   Plastic Strain definition  #
  # ---------------------------- #

 
  #Hooke's law in 3 dimensions
  def sigma(v):
    epsilon=sym(grad(v)) #definition of epsilion 
    n = len(v) #matrix order
    return 2.0*mu*epsilon + lmbda*tr(epsilon)*Identity(n) #formula


  #TASK Parametrisations of contractions on x (x[0]), y (x[1]), z(x[2]) using 4 parameters

  class InherentStrainFunc(UserExpression):
    def eval(self, value, x):
      #for the parameter utilization please refer the parameter document.
      value[0] = 0. 
      value[1] = 0. 
      value[2] = 0. 
      
      value[3] = 0. 
      value[4] = 0. 
      value[5] = 0. 

      value[6] = 0.
      value[7] = 0.
      value[8] = 0.

      #if x[2]>0.:
        # if you add 0 nothing appear
        # c'est ici qu'il faut jouer pour déformer, met un signe négatif pour que ça grandisse en partant d'en bas
        # de ce que l'on voit des partenaire les pièces ont tendances à de rétracter quand elles snt fixé au plateau

      value[0] = param[0]
      value[4] = param[0]
      value[8] = param[0]

  InherentStrain = InherentStrainFunc(element=T.ufl_element()) #create an object to apply deformations

  InherentStrainInterp = Function(T)
  print("value shape de l'is",InherentStrainInterp.value_shape())
        
  InherentStrainInterp.interpolate(InherentStrain)

  #Finite Element Analysis Section
  u = TrialFunction(V) #nodes displacement amount
  v = TestFunction(V)
  a  = inner(sigma(u), grad(v))*dx
  L = inner(InherentStrain,sym(grad(v)))*dx
        
  u_sol = Function(V) #we create the field of displacements

  #Solving the equation:
  solve(a == L, u_sol, bc) #solving the FEA analysis, within the boundaries defined previoulsy
  #TASK: u_sol is to be compared with target geometry to calculate the NN cost function, could be exported in NumPy to facilitate


  # ------------------ #
  #   IS application   #
  # ------------------ #

  coord = mesh.coordinates() #we get the coordinates of the part's mesh  
  #print('mesh coordinates before u_sol : \n',coord)
  
  
  v2d = vertex_to_dof_map(V)
  v2d = v2d.reshape((-1, mesh.geometry().dim()))
  #print('v2d.shape',v2d.shape)

  #we get the displacements' vector, displacements already calculated
  u_vector=u_sol.vector()
  values=u_vector.get_local() #values 
  #print(type(values),'type of values is','u_sol vector values : \n',values)
  
  #list with the coordinates of the mesh
  mesh_ini=[]

  for i in range(coord.shape[0]):

    mesh_ini.append([coord[i,0],coord[i,1],coord[i,2]])

    #X = V.dofmap().tabulate_all_coordinates(mesh)
    v2d_loc = v2d[i,:]
    #print(' v2d_loc', v2d_loc)
    #print('x[i,0]',coord[i,0])
    coord[i,0] = coord[i,0] + u_vector[v2d_loc[0]] #we apply the displacements' vector
    coord[i,1] = coord[i,1] + u_vector[v2d_loc[1]]
    coord[i,2] = coord[i,2] + u_vector[v2d_loc[2]]

  # we convert the list in array
  mesh_ini__array = np.array(mesh_ini)

  print("")  
  #print('mesh coordinates after u_sol : \n',coord)


  # ------------------------- #
  #   Generate results files  #
  # ------------------------- #

  print("")
  #Create mesh file for visualisation
  #file_mesh = File(out_folder+str_name+"_mesh.pvd")
  #file_mesh  << mesh

  #FileBoundaryMarker = File(out_folder+str_name+"_BoundaryMarker.pvd")
  #FileBoundaryMarker << BoundaryMarker

  #Save results in pvd file for visualisation in para view
  #InherentStrain_file = File(out_folder+str_name+"_InherentStrain.pvd")
  #InherentStrain_file << InherentStrainInterp

  #Save displacement result in txt file for Leopold
  #print('the matrix with (before - after) u_sol is: \n',mesh_ini__array - coord)
  np.savetxt(out_folder+str_name+'_def.txt', ( mesh_ini__array -coord), fmt='%10.5f' )
  #%10.5f: the 10 is number of decimal before the . and 5 the same but after the .

  #Save deformation result in pvd file
  file_displacement = File(out_folder+str_name+"_i000_j000_k001_Displacement.pvd")
  file_displacement << u_sol
  print("")
  print("Results files created with success")
  print("")

# %% [markdown]
# Now we apply the function to the dataset:

# %%
'''
NORMAL CONFIG
'''

#We have here the path to the folder with the msh files and the path where we want the results:
dataset = 'drive/MyDrive/Fenics/Test/meshed'
results_folder = '/content/drive/MyDrive/Fenics/Test/results/'

#We have the parameters for the IS 
i = -775.28
#j = 5846.18 #for bending

parameters = [i, j, k]


#we want to apply the IS function to the dataset:
with os.scandir(dataset) as entries:
  my_optimi = []
  for my_msh in entries: #we scan the folder to get the .msh files
    shape=my_msh.name
    str_name,ext = os.path.splitext(shape)
    if ext =='.msh':
      my_optimi.append(str(shape))
      try: 
        InherentStrain(dataset,shape,results_folder,parameters)
      except Exception as exception:
        print(exception)
        print("this file has a problem")
        print("")
        pass

# %% [markdown]
# # **4-Results as .stl**
# The following block is a converter to pass to *.vtu*, which is the result of the IS, to an *.stl* or *.obj* file. Inside the code, you have a selector to choose the format between *.stl* or *.obj*.
# Keep the converter in *.stl* to use Shuo's code.

# %%
'''
THIS BLOCK contains a vtk to stl converter
'''

import vtk

def converter(indir, outdir):
    files = os.listdir(indir)
    for f in files:
        if f.endswith('.vtu'): #we just cnvert .vtu files
            files = os.path.join(indir,f)
            reader = vtk.vtkXMLUnstructuredGridReader() #we read the .vtu file with this reader cause the .vtu file is a UnstructuredGrid type
            reader.SetFileName(files)
            reader.Update() # we ahve to update
            output = reader.GetOutput()
            fileName=f.split('.')[0]

              # ----------- #
              #   Selector  #
              # ----------- #
            
            extension = '.stl' #choose the type of output file: .stl or .obj
            the_converted = outdir + fileName + extension
            if extension == '.stl':
              writer = vtk.vtkSTLWriter() #we create the .stl file here
            if extension == '.obj':
              writer = vtk.vtkOBJWriter() #we create the .obj file here            
            writer.SetFileName(the_converted)

            surface_filter = vtk.vtkDataSetSurfaceFilter() #we extract the surface
            surface_filter.SetInputConnection(reader.GetOutputPort())
            triangle_filter = vtk.vtkTriangleFilter()
            triangle_filter.SetInputConnection(surface_filter.GetOutputPort())

            writer.SetInputConnection(triangle_filter.GetOutputPort())
            writer.Write() #we write the stl files

            if writer.Write() == 1:
              print(datetime.datetime.now())
              print("Conversion to",extension, 'is done. Look:' ,the_converted)

# %%
#We have here the path to the folder with the results files and the path where we want converted results:
results_fenics = '/content/drive/MyDrive/Fenics/Test/results/'
stl_converted = '/content/drive/MyDrive/Fenics/Test/resulta_stl/'

#we convert the files from fenics (that are .vtu) to .stl files:
converter(results_fenics, stl_converted)
